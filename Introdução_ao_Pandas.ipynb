# %% [markdown]
# # Desvendando o Pandas

# %% [markdown]
# ## 1. Carregue suas ferramentas

# %%
# Importar biblioteca Pandas
import pandas as pd

# %%
# Importar o dataset

dataset = pd.read_csv('spotify_songs.csv', sep=',', skiprows=None)
dataset

# pd.DataFrame(): cria um DataFrame a partir de uma lista de listas ou uma matriz.
# pd.read_excel(): importa um arquivo Excel para um DataFrame.

#  O (sep=',') é colocado para indicar qual o separador de dados
# neste caso, o csv já esta separando os dados por ',', portanto o (sep=',') não era necessário. Foi colocado para fins didáticos.
# Out:
#                      track_id                               track_name  \
# 0      6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - ...
# 1      0r7CVbZTWZgbTCYdfa2P31          Memories - Dillon Francis Remix
# 2      1z1Hg7Vb0AhHDiEmnDE79l          All the Time - Don Diablo Remix
# 3      75FpbthrwQmzHlBJLuGdC7        Call You Mine - Keanu Silva Remix
# 4      1e8PAfcKUYoKkxPhrHqw4x  Someone You Loved - Future Humans Remix
# ...                       ...                                      ...
# 32828  7bxnKAamR3snQ1VGLuVfC1     City Of Lights - Official Radio Edit
# 32829  5Aevni09Em4575077nkWHz      Closer - Sultan & Ned Shepard Remix
# 32830  7ImMqPP3Q1yfUHvsdn7wEo             Sweet Surrender - Radio Edit
# 32831  2m69mhnfQ1Oq6lGtXuYhgX           Only For You - Maor Levi Remix
# 32832  29zWqhca3zt5NsckZqDf6c                   Typhoon - Original Mix
#
#            track_artist  track_popularity          track_album_id  \
# 0            Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1              Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2          Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3      The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4         Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# ...                 ...               ...                     ...
# 32828      Lush & Simon                42  2azRoBBWEEEYhqV6sb7JrT
# 32829    Tegan and Sara                20  6kD6KLxj7s8eCE3ABvAyf5
# 32830       Starkillers                14  0ltWNSY9JgxoIZO4VzuCa6
# 32831            Mat Zo                15  1fGrOkHnHJcStl14zNx8Jy
# 32832      Julian Calor                27  0X3mUOm6MhxR7PzxG95rAo
#
#                               track_album_name track_album_release_date  \
# 0      I Don't Care (with Justin Bieber) [L...               2019-06-14
# 1              Memories (Dillon Francis Remix)               2019-12-13
# 2              All the Time (Don Diablo Remix)               2019-07-05
# 3                  Call You Mine - The Remixes               2019-07-19
# 4      Someone You Loved (Future Humans Remix)               2019-03-05
# ...                                        ...                      ...
# 32828               City Of Lights (Vocal Mix)               2014-04-28
# 32829                           Closer Remixed               2013-03-08
# 32830             Sweet Surrender (Radio Edit)               2014-04-21
# 32831                   Only For You (Remixes)               2014-01-01
# 32832                            Typhoon/Storm               2014-03-03
#
#          playlist_name             playlist_id playlist_genre  ... key  \
# 0            Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6
# 1            Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11
# 2            Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1
# 3            Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7
# 4            Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1
# ...                ...                     ...            ...  ...  ..
# 32828  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   2
# 32829  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   0
# 32830  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   6
# 32831  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   2
# 32832  ♥ EDM LOVE 2020  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   5
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0        -2.634     1       0.0583      0.102000          0.000000    0.0653
# 1        -4.969     1       0.0373      0.072400          0.004210    0.3570
# 2        -3.432     0       0.0742      0.079400          0.000023    0.1100
# 3        -3.778     1       0.1020      0.028700          0.000009    0.2040
# 4        -4.672     1       0.0359      0.080300          0.000000    0.0833
# ...         ...   ...          ...           ...               ...       ...
# 32828    -1.814     1       0.0936      0.076600          0.000000    0.0668
# 32829    -4.462     1       0.0420      0.001710          0.004270    0.3750
# 32830    -4.899     0       0.0481      0.108000          0.000001    0.1500
# 32831    -3.361     1       0.1090      0.007920          0.127000    0.3430
# 32832    -4.571     0       0.0385      0.000133          0.341000    0.7420
#
#        valence    tempo  duration_ms
# 0       0.5180  122.036       194754
# 1       0.6930   99.972       162600
# 2       0.6130  124.008       176616
# 3       0.2770  121.956       169093
# 4       0.7250  123.976       189052
# ...        ...      ...          ...
# 32828   0.2100  128.170       204375
# 32829   0.4000  128.041       353120
# 32830   0.4360  127.989       210112
# 32831   0.3080  128.008       367432
# 32832   0.0894  127.984       337500
#
# [32833 rows x 23 columns]

# %% [markdown]
# **Skipirown:** O parâmetro skiprows na função pd.read_csv do Pandas serve para ignorar um determinado número de linhas ao importar um arquivo CSV. Ele permite que você exclua linhas indesejadas, como cabeçalhos não informativos, linhas em branco ou comentários, antes de converter o arquivo em um DataFrame.
#
# Há diversas maneiras de utilizar o skiprows:
#
# Inteiro: Passando um inteiro como valor, você indica a quantidade de linhas a serem ignoradas a partir do início do arquivo. Por exemplo, skiprows=2 ignoraria as duas primeiras linhas.
#
# Lista de inteiros: Você pode fornecer uma lista de números de linhas específicos a serem ignoradas. Por exemplo, skiprows=[1,3] ignoraria a segunda e a quarta linha.
#
# Função: Você pode passar uma função que recebe um index como argumento e retorna True para as linhas que devem ser ignoradas. Isso permite filtrar as linhas com base em critérios mais complexos.
#
# None (valor padrão): Se não for especificado, o Pandas assume que a primeira linha do arquivo é o cabeçalho e a lê como índices das colunas.
# No seu exemplo específico, skiprows=None significa que nenhuma linha será ignorada e o Pandas lerá todas as linhas do arquivo.
#
# Aqui estão alguns motivos para usar o skiprows:
#
# Limpar o cabeçalho: Se o arquivo possui um cabeçalho não informativo ou incorreto, você pode ignorá-lo para evitar erros de parsing.
# Remover linhas vazias ou comentários: Linhas vazias ou comentários podem atrapalhar a análise de dados.
#
# Ignorar introduções ou footers: Alguns arquivos possuem introduções ou footers com informações não relevantes para a análise.
# Espero que isso esclareça o significado e o uso do parâmetro skiprows do Pandas. Se você tiver mais dúvidas, não hesite em perguntar!

# %%
# Define configuracões padrões do Pandas
# max_colwidth=40: Limita a largura das colunas a 40 caracteres.

pd.set_option('max_colwidth', 40)
pd.get_option('max_colwidth')
# Out:
# 40

# %%
## Visualizar as primeiras linhas. O espaco (), em branco indica as primeiras 5 linhas.
## Com número indica as primeiras linhas, no caso abaixo até 6
dataset.head()
# Out:
#                  track_id                               track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - ...
# 1  0r7CVbZTWZgbTCYdfa2P31          Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l          All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7        Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x  Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                           track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [L...               2019-06-14
# 1          Memories (Dillon Francis Remix)               2019-12-13
# 2          All the Time (Don Diablo Remix)               2019-07-05
# 3              Call You Mine - The Remixes               2019-07-19
# 4  Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]

# %%
dataset.head(6)
# Out:
#                  track_id                               track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - ...
# 1  0r7CVbZTWZgbTCYdfa2P31          Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l          All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7        Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x  Someone You Loved - Future Humans Remix
# 5  7fvUMiyapMsRRxr07cU8Ef  Beautiful People (feat. Khalid) - Ja...
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# 5        Ed Sheeran                67  2yiy9cd2QktrNvWC2EUi0k
#
#                           track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [L...               2019-06-14
# 1          Memories (Dillon Francis Remix)               2019-12-13
# 2          All the Time (Don Diablo Remix)               2019-07-05
# 3              Call You Mine - The Remixes               2019-07-19
# 4  Someone You Loved (Future Humans Remix)               2019-03-05
# 5  Beautiful People (feat. Khalid) [Jac...               2019-07-11
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
# 5     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   8    -5.385
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
# 5     1       0.1270        0.0799          0.000000    0.1430    0.585
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
# 5  124.982       163049
#
# [6 rows x 23 columns]

# %%
# Para ver as ultimas 5 linhas no final do arquivo
dataset.tail()
# Out:
#                      track_id                            track_name  \
# 32828  7bxnKAamR3snQ1VGLuVfC1  City Of Lights - Official Radio Edit
# 32829  5Aevni09Em4575077nkWHz   Closer - Sultan & Ned Shepard Remix
# 32830  7ImMqPP3Q1yfUHvsdn7wEo          Sweet Surrender - Radio Edit
# 32831  2m69mhnfQ1Oq6lGtXuYhgX        Only For You - Maor Levi Remix
# 32832  29zWqhca3zt5NsckZqDf6c                Typhoon - Original Mix
#
#          track_artist  track_popularity          track_album_id  \
# 32828    Lush & Simon                42  2azRoBBWEEEYhqV6sb7JrT
# 32829  Tegan and Sara                20  6kD6KLxj7s8eCE3ABvAyf5
# 32830     Starkillers                14  0ltWNSY9JgxoIZO4VzuCa6
# 32831          Mat Zo                15  1fGrOkHnHJcStl14zNx8Jy
# 32832    Julian Calor                27  0X3mUOm6MhxR7PzxG95rAo
#
#                    track_album_name track_album_release_date    playlist_name  \
# 32828    City Of Lights (Vocal Mix)               2014-04-28  ♥ EDM LOVE 2020
# 32829                Closer Remixed               2013-03-08  ♥ EDM LOVE 2020
# 32830  Sweet Surrender (Radio Edit)               2014-04-21  ♥ EDM LOVE 2020
# 32831        Only For You (Remixes)               2014-01-01  ♥ EDM LOVE 2020
# 32832                 Typhoon/Storm               2014-03-03  ♥ EDM LOVE 2020
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 32828  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   2    -1.814     1
# 32829  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   0    -4.462     1
# 32830  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   6    -4.899     0
# 32831  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   2    -3.361     1
# 32832  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   5    -4.571     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 32828       0.0936      0.076600          0.000000    0.0668   0.2100
# 32829       0.0420      0.001710          0.004270    0.3750   0.4000
# 32830       0.0481      0.108000          0.000001    0.1500   0.4360
# 32831       0.1090      0.007920          0.127000    0.3430   0.3080
# 32832       0.0385      0.000133          0.341000    0.7420   0.0894
#
#          tempo  duration_ms
# 32828  128.170       204375
# 32829  128.041       353120
# 32830  127.989       210112
# 32831  128.008       367432
# 32832  127.984       337500
#
# [5 rows x 23 columns]

# %%
#use o display para visualizar os dois juntos
display(dataset.head())
display(dataset.tail())
# Out:
#                  track_id                               track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - ...
# 1  0r7CVbZTWZgbTCYdfa2P31          Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l          All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7        Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x  Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                           track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [L...               2019-06-14
# 1          Memories (Dillon Francis Remix)               2019-12-13
# 2          All the Time (Don Diablo Remix)               2019-07-05
# 3              Call You Mine - The Remixes               2019-07-19
# 4  Someone You Loved (Future Humans Remix)               2019-03-05
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
#
# [5 rows x 23 columns]
#                      track_id                            track_name  \
# 32828  7bxnKAamR3snQ1VGLuVfC1  City Of Lights - Official Radio Edit
# 32829  5Aevni09Em4575077nkWHz   Closer - Sultan & Ned Shepard Remix
# 32830  7ImMqPP3Q1yfUHvsdn7wEo          Sweet Surrender - Radio Edit
# 32831  2m69mhnfQ1Oq6lGtXuYhgX        Only For You - Maor Levi Remix
# 32832  29zWqhca3zt5NsckZqDf6c                Typhoon - Original Mix
#
#          track_artist  track_popularity          track_album_id  \
# 32828    Lush & Simon                42  2azRoBBWEEEYhqV6sb7JrT
# 32829  Tegan and Sara                20  6kD6KLxj7s8eCE3ABvAyf5
# 32830     Starkillers                14  0ltWNSY9JgxoIZO4VzuCa6
# 32831          Mat Zo                15  1fGrOkHnHJcStl14zNx8Jy
# 32832    Julian Calor                27  0X3mUOm6MhxR7PzxG95rAo
#
#                    track_album_name track_album_release_date    playlist_name  \
# 32828    City Of Lights (Vocal Mix)               2014-04-28  ♥ EDM LOVE 2020
# 32829                Closer Remixed               2013-03-08  ♥ EDM LOVE 2020
# 32830  Sweet Surrender (Radio Edit)               2014-04-21  ♥ EDM LOVE 2020
# 32831        Only For You (Remixes)               2014-01-01  ♥ EDM LOVE 2020
# 32832                 Typhoon/Storm               2014-03-03  ♥ EDM LOVE 2020
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 32828  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   2    -1.814     1
# 32829  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   0    -4.462     1
# 32830  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   6    -4.899     0
# 32831  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   2    -3.361     1
# 32832  6jI1gFr6ANFtT8MmTvA2Ux            edm  ...   5    -4.571     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 32828       0.0936      0.076600          0.000000    0.0668   0.2100
# 32829       0.0420      0.001710          0.004270    0.3750   0.4000
# 32830       0.0481      0.108000          0.000001    0.1500   0.4360
# 32831       0.1090      0.007920          0.127000    0.3430   0.3080
# 32832       0.0385      0.000133          0.341000    0.7420   0.0894
#
#          tempo  duration_ms
# 32828  128.170       204375
# 32829  128.041       353120
# 32830  127.989       210112
# 32831  128.008       367432
# 32832  127.984       337500
#
# [5 rows x 23 columns]

# %% [markdown]
# # 2. Informações sobre o Dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32833 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32833 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32833 non-null  int64
#  4   track_album_id            32833 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32833 non-null  object
#  7   playlist_name             32833 non-null  object
#  8   playlist_id               32833 non-null  object
#  9   playlist_genre            32833 non-null  object
#  10  playlist_subgenre         32833 non-null  object
#  11  danceability              32833 non-null  float64
#  12  energy                    32833 non-null  float64
#  13  key                       32833 non-null  int64
#  14  loudness                  32833 non-null  float64
#  15  mode                      32833 non-null  int64
#  16  speechiness               32833 non-null  float64
#  17  acousticness              32833 non-null  float64
#  18  instrumentalness          32833 non-null  float64
#  19  liveness                  32833 non-null  float64
#  20  valence                   32833 non-null  float64
#  21  tempo                     32833 non-null  float64
#  22  duration_ms               32833 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 5.8+ MB

# %%
dataset.shape
# Indica que temos 32833 linhas e 23 colunas
# Out:
# (32833, 23)

# %%
dataset.shape[0]
# mostra apenas o número de linhas
# Out:
# 32833

# %%
dataset.shape[1]
# mostra apenas o número de colunas
# Out:
# 23

# %%
dataset.columns
# Out:
# Index(['track_id', 'track_name', 'track_artist', 'track_popularity',
#        'track_album_id', 'track_album_name', 'track_album_release_date',
#        'playlist_name', 'playlist_id', 'playlist_genre', 'playlist_subgenre',
#        'danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'duration_ms'],
#       dtype='object')

# %%
# mostra a quantidade de linhas
len(dataset)
# Out:
# 32833

# %%
#  retorna o número de valores únicos em uma coluna ou DataFrame
dataset.nunique()
# Out:
# track_id                    28356
# track_name                  23449
# track_artist                10692
# track_popularity              101
# track_album_id              22545
# track_album_name            19743
# track_album_release_date     4530
# playlist_name                 449
# playlist_id                   471
# playlist_genre                  6
# playlist_subgenre              24
# danceability                  822
# energy                        952
# key                            12
# loudness                    10222
# mode                            2
# speechiness                  1270
# acousticness                 3731
# instrumentalness             4729
# liveness                     1624
# valence                      1362
# tempo                       17684
# duration_ms                 19785
# dtype: int64

# %% [markdown]
# ## Índices da tabela

# %%
dataset.index

# Mostra que o índice comeca com 0, possui 7047 linhas, numeradas de 0 a 7046 e é incrementado de 1 em 1.
# Out:
# RangeIndex(start=0, stop=32833, step=1)

# %% [markdown]
# Se quiser estabelecer uma coluna como índice é só usar set_index, por exemplo:
#
# df.set_index('nome da coluna') # para uma coluna
# df.set_index(['nome da coluna 1', 'nome da coluna 2', ..., 'nome da coluna n'] # para varias colunas
# df.set_index([pd.index)[1,2,3,4...],'nome do indice') # pra criar um indice novo do zero
#
# ---

# %%
# Seleciona a linha específica, no caso a linha dentro do índice 3
dataset.loc[3]
# Out:
# track_id                               75FpbthrwQmzHlBJLuGdC7
# track_name                  Call You Mine - Keanu Silva Remix
# track_artist                                 The Chainsmokers
# track_popularity                                           60
# track_album_id                         1nqYsOef1yKKuGOVchbsk6
# track_album_name                  Call You Mine - The Remixes
# track_album_release_date                           2019-07-19
# playlist_name                                       Pop Remix
# playlist_id                            37i9dQZF1DXcZDD7cfEKhW
# playlist_genre                                            pop
# playlist_subgenre                                   dance pop
# danceability                                            0.718
# energy                                                   0.93
# key                                                         7
# loudness                                               -3.778
# mode                                                        1
# speechiness                                             0.102
# acousticness                                           0.0287
# instrumentalness                                     0.000009
# liveness                                                0.204
# valence                                                 0.277
# tempo                                                 121.956
# duration_ms                                            169093
# Name: 3, dtype: object

# %%
dataset.loc[0:3]
# Out:
#                  track_id                               track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - ...
# 1  0r7CVbZTWZgbTCYdfa2P31          Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l          All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7        Call You Mine - Keanu Silva Remix
#
#        track_artist  track_popularity          track_album_id  \
# 0        Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
#
#                           track_album_name track_album_release_date  \
# 0  I Don't Care (with Justin Bieber) [L...               2019-06-14
# 1          Memories (Dillon Francis Remix)               2019-12-13
# 2          All the Time (Don Diablo Remix)               2019-07-05
# 3              Call You Mine - The Remixes               2019-07-19
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0583        0.1020          0.000000    0.0653    0.518
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
#
#      tempo  duration_ms
# 0  122.036       194754
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
#
# [4 rows x 23 columns]

# %%
# Retorna as linhas duplicadas
dataset.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32828    False
# 32829    False
# 32830    False
# 32831    False
# 32832    False
# Length: 32833, dtype: bool

# %%
# Soma o número de linhas duplicadas
dataset.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Análise de dados

# %% [markdown]
# ## Filtros

# %%
dataset.loc[1]
# Out:
# track_id                             0r7CVbZTWZgbTCYdfa2P31
# track_name                  Memories - Dillon Francis Remix
# track_artist                                       Maroon 5
# track_popularity                                         67
# track_album_id                       63rPSO264uRjW1X5E6cWv6
# track_album_name            Memories (Dillon Francis Remix)
# track_album_release_date                         2019-12-13
# playlist_name                                     Pop Remix
# playlist_id                          37i9dQZF1DXcZDD7cfEKhW
# playlist_genre                                          pop
# playlist_subgenre                                 dance pop
# danceability                                          0.726
# energy                                                0.815
# key                                                      11
# loudness                                             -4.969
# mode                                                      1
# speechiness                                          0.0373
# acousticness                                         0.0724
# instrumentalness                                    0.00421
# liveness                                              0.357
# valence                                               0.693
# tempo                                                99.972
# duration_ms                                          162600
# Name: 1, dtype: object

# %%
dataset.loc[1:5]
# Out:
#                  track_id                               track_name  \
# 1  0r7CVbZTWZgbTCYdfa2P31          Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l          All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7        Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x  Someone You Loved - Future Humans Remix
# 5  7fvUMiyapMsRRxr07cU8Ef  Beautiful People (feat. Khalid) - Ja...
#
#        track_artist  track_popularity          track_album_id  \
# 1          Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# 5        Ed Sheeran                67  2yiy9cd2QktrNvWC2EUi0k
#
#                           track_album_name track_album_release_date  \
# 1          Memories (Dillon Francis Remix)               2019-12-13
# 2          All the Time (Don Diablo Remix)               2019-07-05
# 3              Call You Mine - The Remixes               2019-07-19
# 4  Someone You Loved (Future Humans Remix)               2019-03-05
# 5  Beautiful People (feat. Khalid) [Jac...               2019-07-11
#
#   playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
# 5     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   8    -5.385
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 1     1       0.0373        0.0724          0.004210    0.3570    0.693
# 2     0       0.0742        0.0794          0.000023    0.1100    0.613
# 3     1       0.1020        0.0287          0.000009    0.2040    0.277
# 4     1       0.0359        0.0803          0.000000    0.0833    0.725
# 5     1       0.1270        0.0799          0.000000    0.1430    0.585
#
#      tempo  duration_ms
# 1   99.972       162600
# 2  124.008       176616
# 3  121.956       169093
# 4  123.976       189052
# 5  124.982       163049
#
# [5 rows x 23 columns]

# %%
#seleciona as linhas de 1:5 e a coluna específica
dataset.loc[1:5, 'loudness']
# Out:
# 1   -4.969
# 2   -3.432
# 3   -3.778
# 4   -4.672
# 5   -5.385
# Name: loudness, dtype: float64

# %%
#de 0:5 esta definindo o número de linhas e de 0:4 o número de colunas
# Para isso usa-se o ILOC
dataset.iloc[0:5, 0:4]
# Out:
#                  track_id                               track_name  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - ...
# 1  0r7CVbZTWZgbTCYdfa2P31          Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l          All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7        Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x  Someone You Loved - Future Humans Remix
#
#        track_artist  track_popularity
# 0        Ed Sheeran                66
# 1          Maroon 5                67
# 2      Zara Larsson                70
# 3  The Chainsmokers                60
# 4     Lewis Capaldi                69

# %%
dataset['loudness'].dtype
# Out:
# dtype('float64')

# %%
dataset['loudness'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       -2.634
# 1       -4.969
# 2       -3.432
# 3       -3.778
# 4       -4.672
#          ...
# 32828   -1.814
# 32829   -4.462
# 32830   -4.899
# 32831   -3.361
# 32832   -4.571
# Name: loudness, Length: 32833, dtype: float64>

# %%
dataset['track_artist'].dtype
# Out:
# dtype('O')

# %%
dataset.head(15)
# Out:
#                   track_id                               track_name  \
# 0   6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - ...
# 1   0r7CVbZTWZgbTCYdfa2P31          Memories - Dillon Francis Remix
# 2   1z1Hg7Vb0AhHDiEmnDE79l          All the Time - Don Diablo Remix
# 3   75FpbthrwQmzHlBJLuGdC7        Call You Mine - Keanu Silva Remix
# 4   1e8PAfcKUYoKkxPhrHqw4x  Someone You Loved - Future Humans Remix
# 5   7fvUMiyapMsRRxr07cU8Ef  Beautiful People (feat. Khalid) - Ja...
# 6   2OAylPUDDfwRGfe0lYqlCQ          Never Really Over - R3HAB Remix
# 7   6b1RNvAcJjQH73eZO4BLAB  Post Malone (feat. RANI) - GATTÜSO R...
# 8   7bF6tCO3gFb8INrEDcjNT5   Tough Love - Tiësto Remix / Radio Edit
# 9   1IXGILkPm0tOCNeq00kCPa      If I Can't Have You - Gryffin Remix
# 10  3eFJI470ALf1EYjywPRsJy  Cross Me (feat. Chance the Rapper & ...
# 11  3iJeF2izF1QcpCgUc97BLl                    Hate Me - R3HAB Remix
# 12  6e0CvGZf7CouOpYF8toXHC                               Body On My
# 13  3eLdNmnRWr9gIyBcqTSSti  SOS - Laidback Luke Tribute Remix / ...
# 14  55nMnifaQWKe3f9cbwOXwx  Summer Days (feat. Macklemore & Patr...
#
#         track_artist  track_popularity          track_album_id  \
# 0         Ed Sheeran                66  2oCs0DGTsRO98Gh5ZSl2Cx
# 1           Maroon 5                67  63rPSO264uRjW1X5E6cWv6
# 2       Zara Larsson                70  1HoSmj2eLcsrR0vE9gThr4
# 3   The Chainsmokers                60  1nqYsOef1yKKuGOVchbsk6
# 4      Lewis Capaldi                69  7m7vv9wlQ4i0LFuJiE2zsQ
# 5         Ed Sheeran                67  2yiy9cd2QktrNvWC2EUi0k
# 6         Katy Perry                62  7INHYSeusaFlyrHSNxm8qH
# 7          Sam Feldt                69  6703SRPsLkS4bPtMFFJes1
# 8             Avicii                68  7CvAfGvq4RlIwEbT9o8Iav
# 9       Shawn Mendes                67  4QxzbfSsVryEQwvPFEV5Iu
# 10        Ed Sheeran                58  49bXZtlI5kQSqQMSCnSaWO
# 11    Ellie Goulding                67  6e6RVFWdZaoTiLAZOCMnps
# 12       Loud Luxury                67  2R66I0nzp3NnuUlzIGWQ5P
# 13            Avicii                68  7Al4TIo0c5twNLfdOh1y1u
# 14     Martin Garrix                63  2vx3BtBMn8Ed3ygEg1OT2t
#
#                            track_album_name track_album_release_date  \
# 0   I Don't Care (with Justin Bieber) [L...               2019-06-14
# 1           Memories (Dillon Francis Remix)               2019-12-13
# 2           All the Time (Don Diablo Remix)               2019-07-05
# 3               Call You Mine - The Remixes               2019-07-19
# 4   Someone You Loved (Future Humans Remix)               2019-03-05
# 5   Beautiful People (feat. Khalid) [Jac...               2019-07-11
# 6           Never Really Over (R3HAB Remix)               2019-07-26
# 7   Post Malone (feat. RANI) [GATTÜSO Re...               2019-08-29
# 8                 Tough Love (Tiësto Remix)               2019-06-14
# 9       If I Can't Have You (Gryffin Remix)               2019-06-20
# 10  Cross Me (feat. Chance the Rapper & ...               2019-06-21
# 11                    Hate Me (R3HAB Remix)               2019-08-16
# 12                               Body On My               2019-03-29
# 13        SOS (Laidback Luke Tribute Remix)               2019-05-17
# 14  Summer Days (feat. Macklemore & Patr...               2019-07-12
#
#    playlist_name             playlist_id playlist_genre  ... key  loudness  \
# 0      Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -2.634
# 1      Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11    -4.969
# 2      Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -3.432
# 3      Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7    -3.778
# 4      Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.672
# 5      Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   8    -5.385
# 6      Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   5    -4.788
# 7      Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   4    -2.419
# 8      Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   8    -3.562
# 9      Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   2    -4.552
# 10     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6    -6.500
# 11     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   8    -4.918
# 12     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1    -4.675
# 13     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   5    -4.451
# 14     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   5    -4.446
#
#     mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0      1       0.0583       0.10200          0.000000    0.0653    0.518
# 1      1       0.0373       0.07240          0.004210    0.3570    0.693
# 2      0       0.0742       0.07940          0.000023    0.1100    0.613
# 3      1       0.1020       0.02870          0.000009    0.2040    0.277
# 4      1       0.0359       0.08030          0.000000    0.0833    0.725
# 5      1       0.1270       0.07990          0.000000    0.1430    0.585
# 6      0       0.0623       0.18700          0.000000    0.1760    0.152
# 7      0       0.0434       0.03350          0.000005    0.1110    0.367
# 8      1       0.0565       0.02490          0.000004    0.6370    0.366
# 9      1       0.0320       0.05670          0.000000    0.0919    0.590
# 10     1       0.1810       0.14600          0.000005    0.1240    0.752
# 11     1       0.0554       0.14800          0.000000    0.1330    0.329
# 12     1       0.0463       0.03990          0.000000    0.3740    0.687
# 13     0       0.0625       0.01110          0.000000    0.3390    0.678
# 14     0       0.0594       0.00733          0.001830    0.0729    0.238
#
#       tempo  duration_ms
# 0   122.036       194754
# 1    99.972       162600
# 2   124.008       176616
# 3   121.956       169093
# 4   123.976       189052
# 5   124.982       163049
# 6   112.648       187675
# 7   127.936       207619
# 8   127.015       193187
# 9   124.957       253040
# 10  121.984       207894
# 11  123.125       203733
# 12  121.985       192507
# 13  123.919       164516
# 14  126.070       255238
#
# [15 rows x 23 columns]

# %% [markdown]
# # Estatística

# %%
dataset.describe()
# Out:
#        track_popularity  danceability        energy           key  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean          42.477081      0.654850      0.698619      5.374471
# std           24.984074      0.145085      0.180910      3.611657
# min            0.000000      0.000000      0.000175      0.000000
# 25%           24.000000      0.563000      0.581000      2.000000
# 50%           45.000000      0.672000      0.721000      6.000000
# 75%           62.000000      0.761000      0.840000      9.000000
# max          100.000000      0.983000      1.000000     11.000000
#
#            loudness          mode   speechiness  acousticness  \
# count  32833.000000  32833.000000  32833.000000  32833.000000
# mean      -6.719499      0.565711      0.107068      0.175334
# std        2.988436      0.495671      0.101314      0.219633
# min      -46.448000      0.000000      0.000000      0.000000
# 25%       -8.171000      0.000000      0.041000      0.015100
# 50%       -6.166000      1.000000      0.062500      0.080400
# 75%       -4.645000      1.000000      0.132000      0.255000
# max        1.275000      1.000000      0.918000      0.994000
#
#        instrumentalness      liveness       valence         tempo  \
# count      32833.000000  32833.000000  32833.000000  32833.000000
# mean           0.084747      0.190176      0.510561    120.881132
# std            0.224230      0.154317      0.233146     26.903624
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.092700      0.331000     99.960000
# 50%            0.000016      0.127000      0.512000    121.984000
# 75%            0.004830      0.248000      0.693000    133.918000
# max            0.994000      0.996000      0.991000    239.440000
#
#          duration_ms
# count   32833.000000
# mean   225799.811622
# std     59834.006182
# min      4000.000000
# 25%    187819.000000
# 50%    216000.000000
# 75%    253585.000000
# max    517810.000000

# %%
#.sum(): calcula a soma dos valores em uma coluna ou DataFrame.
#.mean(): calcula a média dos valores em uma coluna ou DataFrame.
#.median(): calcula a mediana dos valores em uma coluna ou DataFrame.
#.std(): calcula o desvio padrão dos valores em uma coluna ou DataFrame.

# %% [markdown]
# # Manipulando dados

# %%
# retorna falso quando contem valores e verdadeiro valores nulos
dataset.isna()
# Out:
#        track_id  track_name  track_artist  track_popularity  track_album_id  \
# 0         False       False         False             False           False
# 1         False       False         False             False           False
# 2         False       False         False             False           False
# 3         False       False         False             False           False
# 4         False       False         False             False           False
# ...         ...         ...           ...               ...             ...
# 32828     False       False         False             False           False
# 32829     False       False         False             False           False
# 32830     False       False         False             False           False
# 32831     False       False         False             False           False
# 32832     False       False         False             False           False
#
#        track_album_name  track_album_release_date  playlist_name  playlist_id  \
# 0                 False                     False          False        False
# 1                 False                     False          False        False
# 2                 False                     False          False        False
# 3                 False                     False          False        False
# 4                 False                     False          False        False
# ...                 ...                       ...            ...          ...
# 32828             False                     False          False        False
# 32829             False                     False          False        False
# 32830             False                     False          False        False
# 32831             False                     False          False        False
# 32832             False                     False          False        False
#
#        playlist_genre  ...    key  loudness   mode  speechiness  acousticness  \
# 0               False  ...  False     False  False        False         False
# 1               False  ...  False     False  False        False         False
# 2               False  ...  False     False  False        False         False
# 3               False  ...  False     False  False        False         False
# 4               False  ...  False     False  False        False         False
# ...               ...  ...    ...       ...    ...          ...           ...
# 32828           False  ...  False     False  False        False         False
# 32829           False  ...  False     False  False        False         False
# 32830           False  ...  False     False  False        False         False
# 32831           False  ...  False     False  False        False         False
# 32832           False  ...  False     False  False        False         False
#
#        instrumentalness  liveness  valence  tempo  duration_ms
# 0                 False     False    False  False        False
# 1                 False     False    False  False        False
# 2                 False     False    False  False        False
# 3                 False     False    False  False        False
# 4                 False     False    False  False        False
# ...                 ...       ...      ...    ...          ...
# 32828             False     False    False  False        False
# 32829             False     False    False  False        False
# 32830             False     False    False  False        False
# 32831             False     False    False  False        False
# 32832             False     False    False  False        False
#
# [32833 rows x 23 columns]

# %%
# calcula o número total de valores ausentes em todas as colunas
dataset.isna().sum()
# Out:
# track_id                    0
# track_name                  5
# track_artist                5
# track_popularity            0
# track_album_id              0
# track_album_name            5
# track_album_release_date    0
# playlist_name               0
# playlist_id                 0
# playlist_genre              0
# playlist_subgenre           0
# danceability                0
# energy                      0
# key                         0
# loudness                    0
# mode                        0
# speechiness                 0
# acousticness                0
# instrumentalness            0
# liveness                    0
# valence                     0
# tempo                       0
# duration_ms                 0
# dtype: int64

# %%
#elimina as linhas com valores ausentes
dataset.dropna(inplace=True)

# %%
dataset.duplicated()
#para eliminar linhas duplicadas
dataset.drop_duplicates(inplace=True)

# %%
dataset.track_popularity.value_counts()
# Out:
# 0      2698
# 1       575
# 57      541
# 60      514
# 51      514
#        ...
# 97       22
# 95       15
# 96        7
# 99        4
# 100       2
# Name: track_popularity, Length: 101, dtype: int64

# %%
dataset.loc[(dataset['track_popularity'] >= 95)]
# Out:
#                      track_id                 track_name         track_artist  \
# 139    6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 344    2Fxmhks0bxGSBdJ92vM42m                    bad guy        Billie Eilish
# 687    7k4t7uLgtOxPwTpFmtJNTY                       Tusa              KAROL G
# 689    3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 694    41L3O37CECZt3N7ziG2z7l                      Yummy        Justin Bieber
# ...                       ...                        ...                  ...
# 30207  2b8fOow8UzyDFAE27YhOZM                   Memories             Maroon 5
# 30209  21jGcNKet2qwijlDFuPiPb                    Circles          Post Malone
# 30210  3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 30215  6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 30223  2Fxmhks0bxGSBdJ92vM42m                    bad guy        Billie Eilish
#
#        track_popularity          track_album_id  \
# 139                  96  6EobpC5SDFy5DF50dWNVGF
# 344                  95  0S0KGZnfBGSIssfF54WSJh
# 687                  98  7mKevNHhVnZER3BLgI8O4F
# 689                  97  4i3rAwPw7Ln2YrKDusaWyT
# 694                  95  1SN6N3fNkZk5oXQ9X46QZ3
# ...                 ...                     ...
# 30207                98  3nR9B40hYLKLcR0Eph3Goc
# 30209                98  4g1ZRSobMefqF6nelkgibi
# 30210                97  4i3rAwPw7Ln2YrKDusaWyT
# 30215                96  6EobpC5SDFy5DF50dWNVGF
# 30223                95  0S0KGZnfBGSIssfF54WSJh
#
#                               track_album_name track_album_release_date  \
# 139                  RITMO (Bad Boys For Life)               2019-10-12
# 344    WHEN WE ALL FALL ASLEEP, WHERE DO WE...               2019-03-29
# 687                                       Tusa               2019-11-07
# 689                        everything i wanted               2019-11-13
# 694                                      Yummy               2020-01-03
# ...                                        ...                      ...
# 30207                                 Memories               2019-09-20
# 30209                     Hollywood's Bleeding               2019-09-06
# 30210                      everything i wanted               2019-11-13
# 30215                RITMO (Bad Boys For Life)               2019-10-12
# 30223  WHEN WE ALL FALL ASLEEP, WHERE DO WE...               2019-03-29
#
#                                  playlist_name             playlist_id  \
# 139                                  Dance Pop  37i9dQZF1DWZQaaqNMbbXa
# 344                         Pop Warmup 130 BPM  37i9dQZF1DX3PIAZMcbo2T
# 687                                Todo Éxitos  2ji5tRQVfnhaX1w9FhmSzk
# 689                                Todo Éxitos  2ji5tRQVfnhaX1w9FhmSzk
# 694                                Todo Éxitos  2ji5tRQVfnhaX1w9FhmSzk
# ...                                        ...                     ...
# 30207  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summ...  3xMQTDLOIGvj3lWH5e5x6F
# 30209  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summ...  3xMQTDLOIGvj3lWH5e5x6F
# 30210  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summ...  3xMQTDLOIGvj3lWH5e5x6F
# 30215  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summ...  3xMQTDLOIGvj3lWH5e5x6F
# 30223  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summ...  3xMQTDLOIGvj3lWH5e5x6F
#
#       playlist_genre  ... key  loudness  mode  speechiness  acousticness  \
# 139              pop  ...  10    -7.037     0       0.0657        0.0334
# 344              pop  ...   7   -10.965     1       0.3750        0.3280
# 687              pop  ...   2    -3.280     1       0.2980        0.2950
# 689              pop  ...   6   -14.454     0       0.0994        0.9020
# 694              pop  ...   9    -6.554     0       0.1060        0.4040
# ...              ...  ...  ..       ...   ...          ...           ...
# 30207            edm  ...  11    -7.209     1       0.0546        0.8370
# 30209            edm  ...   0    -3.497     1       0.0395        0.1920
# 30210            edm  ...   6   -14.454     0       0.0994        0.9020
# 30215            edm  ...  10    -7.037     0       0.0657        0.0334
# 30223            edm  ...   7   -10.965     1       0.3750        0.3280
#
#        instrumentalness  liveness  valence    tempo  duration_ms
# 139            0.000840    0.2370    0.667  104.994       221714
# 344            0.130000    0.1000    0.562  135.128       194088
# 687            0.000134    0.0574    0.574  101.085       200960
# 689            0.657000    0.1060    0.243  120.006       245426
# 694            0.000000    0.1210    0.495  145.841       210427
# ...                 ...       ...      ...      ...          ...
# 30207          0.000000    0.0822    0.575   91.019       189486
# 30209          0.002440    0.0863    0.553  120.042       215280
# 30210          0.657000    0.1060    0.243  120.006       245426
# 30215          0.000840    0.2370    0.667  104.994       221714
# 30223          0.130000    0.1000    0.562  135.128       194088
#
# [86 rows x 23 columns]

# %%
#dataset.info()
dataset.loc[(dataset['track_popularity'] >= 95) & (dataset['duration_ms'] > 215280)]
# Out:
#                      track_id                 track_name         track_artist  \
# 139    6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 689    3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 1307   6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 1548   3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 5261   3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 17646  6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 18319  3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 18838  6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 19726  6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 19729  3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 21564  3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 22940  3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 23113  6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
# 30210  3ZCTVFBt2Brf31RLEnCkWJ        everything i wanted        Billie Eilish
# 30215  6cy3ki60hLwimwIje7tALf  RITMO (Bad Boys For Life)  The Black Eyed Peas
#
#        track_popularity          track_album_id           track_album_name  \
# 139                  96  6EobpC5SDFy5DF50dWNVGF  RITMO (Bad Boys For Life)
# 689                  97  4i3rAwPw7Ln2YrKDusaWyT        everything i wanted
# 1307                 96  6EobpC5SDFy5DF50dWNVGF  RITMO (Bad Boys For Life)
# 1548                 97  4i3rAwPw7Ln2YrKDusaWyT        everything i wanted
# 5261                 97  4i3rAwPw7Ln2YrKDusaWyT        everything i wanted
# 17646                96  6EobpC5SDFy5DF50dWNVGF  RITMO (Bad Boys For Life)
# 18319                97  4i3rAwPw7Ln2YrKDusaWyT        everything i wanted
# 18838                96  6EobpC5SDFy5DF50dWNVGF  RITMO (Bad Boys For Life)
# 19726                96  6EobpC5SDFy5DF50dWNVGF  RITMO (Bad Boys For Life)
# 19729                97  4i3rAwPw7Ln2YrKDusaWyT        everything i wanted
# 21564                97  4i3rAwPw7Ln2YrKDusaWyT        everything i wanted
# 22940                97  4i3rAwPw7Ln2YrKDusaWyT        everything i wanted
# 23113                96  6EobpC5SDFy5DF50dWNVGF  RITMO (Bad Boys For Life)
# 30210                97  4i3rAwPw7Ln2YrKDusaWyT        everything i wanted
# 30215                96  6EobpC5SDFy5DF50dWNVGF  RITMO (Bad Boys For Life)
#
#       track_album_release_date                            playlist_name  \
# 139                 2019-10-12                                Dance Pop
# 689                 2019-11-13                              Todo Éxitos
# 1307                2019-10-12  Pop - Pop UK - 2019 - Canadian Pop -...
# 1548                2019-11-13  post-teen alternative, indie, pop (l...
# 5261                2019-11-13                        Music&Other Drugs
# 17646               2019-10-12                                 Global X
# 18319               2019-11-13  2020 Hits & 2019  Hits – Top Global ...
# 18838               2019-10-12                         Reggaeton 2020 ☀
# 19726               2019-10-12  2020 Hits & 2019  Hits – Top Global ...
# 19729               2019-11-13  2020 Hits & 2019  Hits – Top Global ...
# 21564               2019-11-13                 Most Popular 2020 TOP 50
# 22940               2019-11-13                            Pop Hits 2020
# 23113               2019-10-12  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summ...
# 30210               2019-11-13  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summ...
# 30215               2019-10-12  Charts 2020 🔥Top 2020🔥Hits 2020🔥Summ...
#
#                   playlist_id playlist_genre  ... key  loudness  mode  \
# 139    37i9dQZF1DWZQaaqNMbbXa            pop  ...  10    -7.037     0
# 689    2ji5tRQVfnhaX1w9FhmSzk            pop  ...   6   -14.454     0
# 1307   46Cl6dmeiylK6TRGXr7hHe            pop  ...  10    -7.037     0
# 1548   1y42gwI5cuwjBslPyQNfqb            pop  ...   6   -14.454     0
# 5261   5jROYSZSL7cO0jGAqkPx7C            pop  ...   6   -14.454     0
# 17646  37i9dQZF1DWUxHPh2rEiHr          latin  ...  10    -7.037     0
# 18319  4JkkvMpVl4lSioqQjeAL0q          latin  ...   6   -14.454     0
# 18838  7xWuNevFBmwnFEg6wzdCc7          latin  ...  10    -7.037     0
# 19726  4JkkvMpVl4lSioqQjeAL0q          latin  ...  10    -7.037     0
# 19729  4JkkvMpVl4lSioqQjeAL0q          latin  ...   6   -14.454     0
# 21564  1fqkbjEACMlekdddm5aobE            r&b  ...   6   -14.454     0
# 22940  5TDtuKDbOhrfW7C58XnriZ            r&b  ...   6   -14.454     0
# 23113  3xMQTDLOIGvj3lWH5e5x6F            r&b  ...  10    -7.037     0
# 30210  3xMQTDLOIGvj3lWH5e5x6F            edm  ...   6   -14.454     0
# 30215  3xMQTDLOIGvj3lWH5e5x6F            edm  ...  10    -7.037     0
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 139         0.0657        0.0334           0.00084     0.237    0.667
# 689         0.0994        0.9020           0.65700     0.106    0.243
# 1307        0.0657        0.0334           0.00084     0.237    0.667
# 1548        0.0994        0.9020           0.65700     0.106    0.243
# 5261        0.0994        0.9020           0.65700     0.106    0.243
# 17646       0.0657        0.0334           0.00084     0.237    0.667
# 18319       0.0994        0.9020           0.65700     0.106    0.243
# 18838       0.0657        0.0334           0.00084     0.237    0.667
# 19726       0.0657        0.0334           0.00084     0.237    0.667
# 19729       0.0994        0.9020           0.65700     0.106    0.243
# 21564       0.0994        0.9020           0.65700     0.106    0.243
# 22940       0.0994        0.9020           0.65700     0.106    0.243
# 23113       0.0657        0.0334           0.00084     0.237    0.667
# 30210       0.0994        0.9020           0.65700     0.106    0.243
# 30215       0.0657        0.0334           0.00084     0.237    0.667
#
#          tempo  duration_ms
# 139    104.994       221714
# 689    120.006       245426
# 1307   104.994       221714
# 1548   120.006       245426
# 5261   120.006       245426
# 17646  104.994       221714
# 18319  120.006       245426
# 18838  104.994       221714
# 19726  104.994       221714
# 19729  120.006       245426
# 21564  120.006       245426
# 22940  120.006       245426
# 23113  104.994       221714
# 30210  120.006       245426
# 30215  104.994       221714
#
# [15 rows x 23 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32828 entries, 0 to 32832
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   track_id                  32828 non-null  object
#  1   track_name                32828 non-null  object
#  2   track_artist              32828 non-null  object
#  3   track_popularity          32828 non-null  int64
#  4   track_album_id            32828 non-null  object
#  5   track_album_name          32828 non-null  object
#  6   track_album_release_date  32828 non-null  object
#  7   playlist_name             32828 non-null  object
#  8   playlist_id               32828 non-null  object
#  9   playlist_genre            32828 non-null  object
#  10  playlist_subgenre         32828 non-null  object
#  11  danceability              32828 non-null  float64
#  12  energy                    32828 non-null  float64
#  13  key                       32828 non-null  int64
#  14  loudness                  32828 non-null  float64
#  15  mode                      32828 non-null  int64
#  16  speechiness               32828 non-null  float64
#  17  acousticness              32828 non-null  float64
#  18  instrumentalness          32828 non-null  float64
#  19  liveness                  32828 non-null  float64
#  20  valence                   32828 non-null  float64
#  21  tempo                     32828 non-null  float64
#  22  duration_ms               32828 non-null  int64
# dtypes: float64(9), int64(4), object(10)
# memory usage: 6.0+ MB

# %%
dataset['danceability']
# Out:
# 0        0.748
# 1        0.726
# 2        0.675
# 3        0.718
# 4        0.650
#          ...
# 32828    0.428
# 32829    0.522
# 32830    0.529
# 32831    0.626
# 32832    0.603
# Name: danceability, Length: 32828, dtype: float64

# %% [markdown]
# ## Agrupamento

# %%
grupos = dataset.groupby('track_popularity')['track_artist'].value_counts()
grupos
# Out:
# track_popularity  track_artist
# 0                 Ballin Entertainment    42
#                   Javiera Mena            29
#                   Miguel Rios             29
#                   Rick Ross               21
#                   CASIOPEA                20
#                                           ..
# 98                The Weeknd               8
#                   KAROL G                  7
#                   Post Malone              5
# 99                Arizona Zervas           4
# 100               Tones and I              2
# Name: track_artist, Length: 24901, dtype: int64
